# %%
import os
import sys

import gymnasium as gym
import numpy as np
import ray
import torch
from gymnasium import spaces
from ray import tune
from ray.rllib.algorithms.dqn import DQN, DQNConfig
from ray.rllib.models import ModelCatalog
from ray.rllib.models.torch.torch_modelv2 import TorchModelV2
from ray.rllib.utils.exploration.epsilon_greedy import EpsilonGreedy
from ray.tune.registry import register_env
from torch import nn

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import core
print(sys.path)

sys.modules['core'] = core
from core.algorithms.amd.amd import AMD, AMDConfig
from core.algorithms.amd.wrappers import \
    MultiAgentEnvFromPettingZooParallel as P2M
from core.environments.wolfpack import wolfpack_env_creator
# Out:
# pygame 2.3.0 (SDL 2.24.2, Python 3.10.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ['/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/thirdparty_files', '/home/quanta/Projects/FoRL-project/test_code', '/home/quanta/.conda/envs/forl-proj/lib/python310.zip', '/home/quanta/.conda/envs/forl-proj/lib/python3.10', '/home/quanta/.conda/envs/forl-proj/lib/python3.10/lib-dynload', '', '/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages', '/home/quanta/Projects/FoRL-project']

# %%
class SimpleMLPModelV2(TorchModelV2, nn.Module):

    def __init__(self, obs_space: gym.Space, act_space: gym.Space, num_outputs, *args, **kwargs):
        TorchModelV2.__init__(self, obs_space, act_space, num_outputs, *args, **kwargs)
        nn.Module.__init__(self)

        self.flattened_obs_space = spaces.flatten_space(obs_space)
        self.obs_space = obs_space
        self.action_space = act_space

        self.model = nn.Sequential(
            nn.Flatten(start_dim=1, end_dim=-1),
            nn.Linear(self.flattened_obs_space.shape[0], 128),
            nn.ReLU(),
            nn.Linear(128, 32),
            nn.ReLU(),
        )

        self.policy_fn = nn.Linear(32, num_outputs)
        self.value_fn = nn.Linear(32, 1)

    def forward(self, input_dict, state, seq_lens):
        model_out = self.model(input_dict["obs"].to(torch.float32) / 255)
        self._value_out = self.value_fn(model_out)
        return self.policy_fn(model_out), state

    def value_function(self):
        return self._value_out.flatten()

# %%
ray.init()
# Out:
# 2023-05-21 12:41:09,054	INFO worker.py:1553 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.10.4', ray_version='2.3.1', ray_commit='5f14cee8dfc6d61ec4fd3bc2c440f9944e92b33a', address_info={'node_ip_address': '192.168.3.2', 'raylet_ip_address': '192.168.3.2', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2023-05-21_12-41-07_327074_41809/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2023-05-21_12-41-07_327074_41809/sockets/raylet', 'webui_url': '', 'session_dir': '/tmp/ray/session_2023-05-21_12-41-07_327074_41809', 'metrics_export_port': 40816, 'gcs_address': '192.168.3.2:58645', 'address': '192.168.3.2:58645', 'dashboard_agent_listen_port': 52365, 'node_id': 'b0c71db01c8a783b45fad49e9d7c5f9a0bcc536938d994313948f3b6'})

# %%
# register env and model
env_name = 'wolfpack'
register_env(env_name, lambda config: P2M(wolfpack_env_creator(config)))
ModelCatalog.register_custom_model("SimpleMLPModelV2", SimpleMLPModelV2)

# %%
# config for dqn
config = DQNConfig().multi_agent(
    policies=['predator', 'prey'],
    policy_mapping_fn=(lambda agent_id, *args, **kwargs: {
        'wolf_1': 'predator',
        'wolf_2': 'predator',
        'prey': 'prey',
    }[agent_id]),
).environment(
    env=env_name,
    env_config={
        'r_lone': 1.0,
        'r_team': 5.0,
        'r_prey': 0.0,
        'coop_radius': 4,
        'max_cycles': 1000,
    },
    clip_actions=True,
).rollouts(
    num_rollout_workers=4,
    rollout_fragment_length=128,
).training(
    model={
        "custom_model": "SimpleMLPModelV2",
        "custom_model_config": {},
    },
    train_batch_size=1000,
    lr=2e-5,
    gamma=0.99,
    v_min=0.0,
    v_max=10.0,
    # double_q=True,
).debugging(log_level="ERROR").framework(framework="torch").resources(
    num_gpus=int(os.environ.get("RLLIB_NUM_GPUS", "0")),
    num_cpus_per_worker=3,
)
explore_config = {
    "type": EpsilonGreedy,
    "initial_epsilon": 1.0,
    "final_epsilon": 0.1,
    "epsilon_timesteps": 100000,
}
config.explore = True,
config.exploration_config = explore_config

# %%
# load checkpoint init weight
algo = config.build().load_checkpoint('/home/quanta/ray_results/wolfpack/dqn/DQN_wolfpack_5e5a5_00000_0_2023-05-21_12-22-20/checkpoint_000010')

# worker = algo.workers.local_worker()
# policy_map = worker.policy_map()
# for policy_id in policy_map.keys():
#     print(policy_id)
# Out:
# 2023-05-21 12:41:10,439	INFO algorithm.py:506 -- Current log_level is ERROR. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (RolloutWorker pid=46213) 2023-05-21 12:41:13,810	ERROR serialization.py:371 -- No module named 'core'
# (RolloutWorker pid=46213) Traceback (most recent call last):
# (RolloutWorker pid=46213)   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 369, in deserialize_objects
# (RolloutWorker pid=46213)     obj = self._deserialize_object(data, metadata, object_ref)
# (RolloutWorker pid=46213)   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 252, in _deserialize_object
# (RolloutWorker pid=46213)     return self._deserialize_msgpack_data(data, metadata_fields)
# (RolloutWorker pid=46213)   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 207, in _deserialize_msgpack_data
# (RolloutWorker pid=46213)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (RolloutWorker pid=46213)   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 197, in _deserialize_pickle5_data
# (RolloutWorker pid=46213)     obj = pickle.loads(in_band)
# (RolloutWorker pid=46213) ModuleNotFoundError: No module named 'core'
# (RolloutWorker pid=46212) 2023-05-21 12:41:13,776	ERROR serialization.py:371 -- No module named 'core'
# (RolloutWorker pid=46212) Traceback (most recent call last):
# (RolloutWorker pid=46212)   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 369, in deserialize_objects
# (RolloutWorker pid=46212)     obj = self._deserialize_object(data, metadata, object_ref)
# (RolloutWorker pid=46212)   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 252, in _deserialize_object
# (RolloutWorker pid=46212)     return self._deserialize_msgpack_data(data, metadata_fields)
# (RolloutWorker pid=46212)   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 207, in _deserialize_msgpack_data
# (RolloutWorker pid=46212)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (RolloutWorker pid=46212)   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 197, in _deserialize_pickle5_data
# (RolloutWorker pid=46212)     obj = pickle.loads(in_band)
# (RolloutWorker pid=46212) ModuleNotFoundError: No module named 'core'
# (RolloutWorker pid=46212) 2023-05-21 12:41:13,807	ERROR worker.py:772 -- Exception raised in creation task: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=46212, ip=192.168.3.2, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x7f15926c9e10>)
# (RolloutWorker pid=46212)   At least one of the input arguments for this task could not be computed:
# (RolloutWorker pid=46212) ray.exceptions.RaySystemError: System error: No module named 'core'
# (RolloutWorker pid=46212) traceback: Traceback (most recent call last):
# (RolloutWorker pid=46212) ModuleNotFoundError: No module named 'core'
# 2023-05-21 12:41:13,901	ERROR actor_manager.py:496 -- Ray error, taking actor 1 out of service. The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=46212, ip=192.168.3.2, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x7f15926c9e10>)
#   At least one of the input arguments for this task could not be computed:
# ray.exceptions.RaySystemError: System error: No module named 'core'
# traceback: Traceback (most recent call last):
# ModuleNotFoundError: No module named 'core'
# 2023-05-21 12:41:13,902	ERROR actor_manager.py:496 -- Ray error, taking actor 2 out of service. The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=46213, ip=192.168.3.2, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x7f7535061db0>)
#   At least one of the input arguments for this task could not be computed:
# ray.exceptions.RaySystemError: System error: No module named 'core'
# traceback: Traceback (most recent call last):
# ModuleNotFoundError: No module named 'core'
# 2023-05-21 12:41:13,902	ERROR actor_manager.py:496 -- Ray error, taking actor 3 out of service. The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=46214, ip=192.168.3.2, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x7ff6a1879ea0>)
#   At least one of the input arguments for this task could not be computed:
# ray.exceptions.RaySystemError: System error: No module named 'core'
# traceback: Traceback (most recent call last):
# ModuleNotFoundError: No module named 'core'
# 2023-05-21 12:41:13,903	ERROR actor_manager.py:496 -- Ray error, taking actor 4 out of service. The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=46215, ip=192.168.3.2, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x7f44f5421de0>)
#   At least one of the input arguments for this task could not be computed:
# ray.exceptions.RaySystemError: System error: No module named 'core'
# traceback: Traceback (most recent call last):
# ModuleNotFoundError: No module named 'core'
# (RolloutWorker pid=46215) 2023-05-21 12:41:13,867	ERROR serialization.py:371 -- No module named 'core'
# (RolloutWorker pid=46215) Traceback (most recent call last):
# (RolloutWorker pid=46215)   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 369, in deserialize_objects
# (RolloutWorker pid=46215)     obj = self._deserialize_object(data, metadata, object_ref)
# (RolloutWorker pid=46215)   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 252, in _deserialize_object
# (RolloutWorker pid=46215)     return self._deserialize_msgpack_data(data, metadata_fields)
# (RolloutWorker pid=46215)   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 207, in _deserialize_msgpack_data
# (RolloutWorker pid=46215)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (RolloutWorker pid=46215)   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 197, in _deserialize_pickle5_data
# (RolloutWorker pid=46215)     obj = pickle.loads(in_band)
# (RolloutWorker pid=46215) ModuleNotFoundError: No module named 'core'
# (RolloutWorker pid=46215) 2023-05-21 12:41:13,899	ERROR worker.py:772 -- Exception raised in creation task: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=46215, ip=192.168.3.2, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x7f44f5421de0>)
# (RolloutWorker pid=46215)   At least one of the input arguments for this task could not be computed:
# (RolloutWorker pid=46215) ray.exceptions.RaySystemError: System error: No module named 'core'
# (RolloutWorker pid=46215) traceback: Traceback (most recent call last):
# (RolloutWorker pid=46215) ModuleNotFoundError: No module named 'core'
# (RolloutWorker pid=46214) 2023-05-21 12:41:13,843	ERROR serialization.py:371 -- No module named 'core'
# (RolloutWorker pid=46214) Traceback (most recent call last):
# (RolloutWorker pid=46214)   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 369, in deserialize_objects
# (RolloutWorker pid=46214)     obj = self._deserialize_object(data, metadata, object_ref)
# (RolloutWorker pid=46214)   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 252, in _deserialize_object
# (RolloutWorker pid=46214)     return self._deserialize_msgpack_data(data, metadata_fields)
# (RolloutWorker pid=46214)   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 207, in _deserialize_msgpack_data
# (RolloutWorker pid=46214)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (RolloutWorker pid=46214)   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 197, in _deserialize_pickle5_data
# (RolloutWorker pid=46214)     obj = pickle.loads(in_band)
# (RolloutWorker pid=46214) ModuleNotFoundError: No module named 'core'
# (RolloutWorker pid=46214) 2023-05-21 12:41:13,874	ERROR worker.py:772 -- Exception raised in creation task: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=46214, ip=192.168.3.2, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x7ff6a1879ea0>)
# (RolloutWorker pid=46214)   At least one of the input arguments for this task could not be computed:
# (RolloutWorker pid=46214) ray.exceptions.RaySystemError: System error: No module named 'core'
# (RolloutWorker pid=46214) traceback: Traceback (most recent call last):
# (RolloutWorker pid=46214) ModuleNotFoundError: No module named 'core'
# (RolloutWorker pid=46213) 2023-05-21 12:41:13,840	ERROR worker.py:772 -- Exception raised in creation task: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=46213, ip=192.168.3.2, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x7f7535061db0>)
# (RolloutWorker pid=46213)   At least one of the input arguments for this task could not be computed:
# (RolloutWorker pid=46213) ray.exceptions.RaySystemError: System error: No module named 'core'
# (RolloutWorker pid=46213) traceback: Traceback (most recent call last):
# (RolloutWorker pid=46213) ModuleNotFoundError: No module named 'core'
# ---------------------------------------------------------------------------
# RayActorError                             Traceback (most recent call last)
# File ~/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/rllib/evaluation/worker_set.py:170, in WorkerSet.__init__(self, env_creator, validate_env, default_policy_class, config, num_workers, local_worker, logdir, _setup, policy_class, trainer_config)
#     169 try:
# --> 170     self._setup(
#     171         validate_env=validate_env,
#     172         config=config,
#     173         num_workers=num_workers,
#     174         local_worker=local_worker,
#     175     )
#     176 # WorkerSet creation possibly fails, if some (remote) workers cannot
#     177 # be initialized properly (due to some errors in the RolloutWorker's
#     178 # constructor).
#
# File ~/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/rllib/evaluation/worker_set.py:240, in WorkerSet._setup(self, validate_env, config, num_workers, local_worker)
#     239 # Create a number of @ray.remote workers.
# --> 240 self.add_workers(
#     241     num_workers,
#     242     validate=config.validate_workers_after_construction,
#     243 )
#     245 # If num_workers > 0 and we don't have an env on the local worker,
#     246 # get the observation- and action spaces for each policy from
#     247 # the first remote worker (which does have an env).
#
# File ~/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/rllib/evaluation/worker_set.py:614, in WorkerSet.add_workers(self, num_workers, validate)
#     613 if not result.ok:
# --> 614     raise result.get()
#
# File ~/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/rllib/utils/actor_manager.py:477, in FaultTolerantActorManager.__fetch_result(self, remote_actor_ids, remote_calls, timeout_seconds, return_obj_refs, mark_healthy)
#     476 try:
# --> 477     result = ray.get(r)
#     478     remote_results.add_result(actor_id, ResultOrError(result=result))
#
# File ~/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/client_mode_hook.py:105, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     104         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105 return func(*args, **kwargs)
#
# File ~/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/worker.py:2382, in get(object_refs, timeout)
#    2381         else:
# -> 2382             raise value
#    2384 if is_individual_id:
#
# RayActorError: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=46212, ip=192.168.3.2, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x7f15926c9e10>)
#   At least one of the input arguments for this task could not be computed:
# ray.exceptions.RaySystemError: System error: No module named 'core'
# traceback: Traceback (most recent call last):
# ModuleNotFoundError: No module named 'core'
#
# During handling of the above exception, another exception occurred:
#
# RaySystemError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 # load checkpoint init weight
# ----> 2 algo = config.build().load_checkpoint('/home/quanta/ray_results/wolfpack/dqn/DQN_wolfpack_5e5a5_00000_0_2023-05-21_12-22-20/checkpoint_000010')
#       4 # worker = algo.workers.local_worker()
#       5 # policy_map = worker.policy_map()
#       6 # for policy_id in policy_map.keys():
#       7 #     print(policy_id)
#
# File ~/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm_config.py:926, in AlgorithmConfig.build(self, env, logger_creator, use_copy)
#     923 if isinstance(self.algo_class, str):
#     924     algo_class = get_trainable_cls(self.algo_class)
# --> 926 return algo_class(
#     927     config=self if not use_copy else copy.deepcopy(self),
#     928     logger_creator=self.logger_creator,
#     929 )
#
# File ~/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:445, in Algorithm.__init__(self, config, env, logger_creator, **kwargs)
#     433 # Initialize common evaluation_metrics to nan, before they become
#     434 # available. We want to make sure the metrics are always present
#     435 # (although their values may be nan), so that Tune does not complain
#     436 # when we use these as stopping criteria.
#     437 self.evaluation_metrics = {
#     438     "evaluation": {
#     439         "episode_reward_max": np.nan,
#    (...)
#     442     }
#     443 }
# --> 445 super().__init__(
#     446     config=config,
#     447     logger_creator=logger_creator,
#     448     **kwargs,
#     449 )
#     451 # Check, whether `training_iteration` is still a tune.Trainable property
#     452 # and has not been overridden by the user in the attempt to implement the
#     453 # algos logic (this should be done now inside `training_step`).
#     454 try:
#
# File ~/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/tune/trainable/trainable.py:169, in Trainable.__init__(self, config, logger_creator, remote_checkpoint_dir, custom_syncer, sync_timeout)
#     167 start_time = time.time()
#     168 self._local_ip = ray.util.get_node_ip_address()
# --> 169 self.setup(copy.deepcopy(self.config))
#     170 setup_time = time.time() - start_time
#     171 if setup_time > SETUP_TIME_THRESHOLD:
#
# File ~/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/rllib/algorithms/algorithm.py:571, in Algorithm.setup(self, config)
#     564 # Only if user did not override `_init()`:
#     565 if _init is False:
#     566     # - Create rollout workers here automatically.
#     567     # - Run the execution plan to create the local iterator to `next()`
#     568     #   in each training iteration.
#     569     # This matches the behavior of using `build_trainer()`, which
#     570     # has been deprecated.
# --> 571     self.workers = WorkerSet(
#     572         env_creator=self.env_creator,
#     573         validate_env=self.validate_env,
#     574         default_policy_class=self.get_default_policy_class(self.config),
#     575         config=self.config,
#     576         num_workers=self.config.num_rollout_workers,
#     577         local_worker=True,
#     578         logdir=self.logdir,
#     579     )
#     581     # TODO (avnishn): Remove the execution plan API by q1 2023
#     582     # Function defining one single training iteration's behavior.
#     583     if self.config._disable_execution_plan_api:
#     584         # Ensure remote workers are initially in sync with the local worker.
#
# File ~/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/rllib/evaluation/worker_set.py:192, in WorkerSet.__init__(self, env_creator, validate_env, default_policy_class, config, num_workers, local_worker, logdir, _setup, policy_class, trainer_config)
#     179 except RayActorError as e:
#     180     # In case of an actor (remote worker) init failure, the remote worker
#     181     # may still exist and will be accessible, however, e.g. calling
#     182     # its `sample.remote()` would result in strange "property not found"
#     183     # errors.
#     184     if e.actor_init_failed:
#     185         # Raise the original error here that the RolloutWorker raised
#     186         # during its construction process. This is to enforce transparency
#    (...)
#     190         # - e.args[0].args[2]: The original Exception (e.g. a ValueError due
#     191         # to a config mismatch) thrown inside the actor.
# --> 192         raise e.args[0].args[2]
#     193     # In any other case, raise the RayActorError as-is.
#     194     else:
#     195         raise e
#
# RaySystemError: System error: No module named 'core'
# traceback: Traceback (most recent call last):
#   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 369, in deserialize_objects
#     obj = self._deserialize_object(data, metadata, object_ref)
#   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 252, in _deserialize_object
#     return self._deserialize_msgpack_data(data, metadata_fields)
#   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 207, in _deserialize_msgpack_data
#     python_objects = self._deserialize_pickle5_data(pickle5_data)
#   File "/home/quanta/.conda/envs/forl-proj/lib/python3.10/site-packages/ray/_private/serialization.py", line 197, in _deserialize_pickle5_data
#     obj = pickle.loads(in_band)
# ModuleNotFoundError: No module named 'core'
